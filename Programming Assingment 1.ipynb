# %% [markdown]
# # Programming Assignment 1 - Miguel Joaquin T. Cariño, 2 ECE-D

# %% [markdown]
# ## A. Word Rotation Problem

# %%
def rotate_word(text):
    return text[1:] + text[0]

# %%
rotate_word("Miguel")
# Out:
# 'iguelM'

# %%
rotate_word("eLectronics")
# Out:
# 'Lectronicse'

# %%
rotate_word("coffee")
# Out:
# 'offeec'

# %% [markdown]
# ## B. Username Builder Problem

# %%
def make_username(firstname, lastname):
    firstname.lower() 
    lastname.lower()
    return firstname.lower() + "."+ lastname.lower()

# %%
make_username("Miguel", "Carino")
# Out:
# 'miguel.carino'

# %%
make_username("Tony", "Stark")
# Out:
# 'tony.stark'

# %% [markdown]
# ## C. BOOKEND SWAP PROBLEM

# %%
def swap_bookends(item):
    first, *middle, last = item
    first = item[0]
    middle = item[1:-1]
    last = item[-1]
    return [last] + [*middle] + [first]

# %%
swap_bookends([1,2,3,4,5,6])
# Out:
# [6, 2, 3, 4, 5, 1]

# %%
swap_bookends([1,9])
# Out:
# [9, 1]

# %%
swap_bookends(["Kimi", "Lewis", "Max"])
# Out:
# ['Max', 'Lewis', 'Kimi']
